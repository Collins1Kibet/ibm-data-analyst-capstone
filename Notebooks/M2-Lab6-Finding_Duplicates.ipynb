# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
num_duplicates = df.duplicated().sum()
print("Number of duplicate rows:", num_duplicates)
# Out:
# Number of duplicate rows: 0

# %%
df_duplicated = df[df.duplicated()]
df_duplicated.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
## Write your code here
subset_cols = ['ResponseId', 'MainBranch', 'Age', 'Country', 'Employment', 'RemoteWork']

duplicates = df[df.duplicated(subset=subset_cols)]  #by default it will keep='first'
duplicates.head()
# Out:
# Empty DataFrame
# ...

# %%
num_duplicates = duplicates.shape[0]
num_duplicates
# Out:
# 64876

# %%
grouped = duplicates.groupby(subset_cols)

identical_counts = {
    col: grouped[col].nunique().eq(1).sum()
    for col in df.columns if col not in subset_cols
}

identical_summary = pd.DataFrame.from_dict(
    identical_counts, orient="index", columns=["Identical_in_groups"]
)

identical_summary
# Out:
#                      Identical_in_groups
# ResponseId                            63
# Age                                   81
# Check                                319
# CodingActivities                      65
# EdLevel                               74
# ...                                  ...
# JobSatPoints_11                       50
# SurveyLength                          95
# SurveyEase                            79
# ConvertedCompYearly                   27
# JobSat                                44
#
# [111 rows x 1 columns]

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
## Write your code here
duplicates_subset = df[df.duplicated(subset=subset_cols, keep=False)]
# Count duplicates per country
country_counts = duplicates_subset['Country'].value_counts().head(15)

# Bar chart
plt.figure(figsize=(12,6))
sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")
plt.xticks(rotation=45, ha='right')
plt.title("Top 15 Countries with Duplicates")
plt.ylabel("Number of Duplicates")
plt.xlabel("Country")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20068\1284365662.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")

# %%
# Pie chart
plt.figure(figsize=(8,8))
plt.pie(country_counts.values, labels=country_counts.index, autopct='%1.1f%%')
plt.title("Duplicate Distribution by Country")
plt.show()

# %%
employment_counts = duplicates_subset['Employment'].value_counts().head(10)

# Bar chart
plt.figure(figsize=(12,6))
sns.barplot(x=employment_counts.index, y=employment_counts.values, palette="viridis")
plt.xticks(rotation=45, ha='right')
plt.title("Distribution of Duplicates by Employment")
plt.ylabel("Number of Duplicates")
plt.xlabel("Employment Type")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20068\3709575005.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=employment_counts.index, y=employment_counts.values, palette="viridis")

# %%
# Pie chart
plt.figure(figsize=(8,8))
plt.pie(employment_counts.values, labels=employment_counts.index, autopct='%1.1f%%')
plt.title("Duplicate Distribution by Employment")
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here
df_cleaned = df.drop_duplicates(subset=['ResponseId'], keep='first')
df_cleaned
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
#
# 1. Document the Process of Identifying and Removing Duplicates
# Step 1: Identifying Full Duplicate Rows
#
# The first step was to detect exact duplicates across all columns.
# Using df.duplicated(), the number of fully duplicated rows was counted, and the first few were displayed for inspection.
#
# num_duplicates = df.duplicated().sum()
# df_duplicated = df[df.duplicated()]
# print(num_duplicates)
# print(df_duplicated.head())
#
# This step provided an understanding of whether the dataset contained repeated entries with completely identical values.
#
#
# Step 2: Identifying Duplicates Based on a Subset of Columns
#
# Because full-row duplication is not always the best criterion, duplicates were also checked using a set of important columns:
#
# subset_cols = ['ResponseId', 'MainBranch', 'Age', 'Country', 'Employment', 'RemoteWork']
# duplicates = df[df.duplicated(subset=subset_cols)]
# duplicates.head()
#
# This revealed partial duplicates—rows that may differ in some fields but represent the same respondent or submission.
#
#
# Step 3: Analyzing Characteristics of Duplicate Groups
#
# To understand how duplicates behave, duplicates were grouped, and other columns were checked for consistency:
#
# grouped = duplicates.groupby(subset_cols)
# identical_counts = {
#    col: grouped[col].nunique().eq(1).sum()
#    for col in df.columns if col not in subset_cols
# }
#
# identical_summary = pd.DataFrame.from_dict(
#     identical_counts, orient="index", columns=["Identical_in_groups"]
# )
#
# identical_summary
#
# This helped identify columns that almost always have identical values within duplicate groups.
# This summary shows how often each column is identical within duplicate groups.
# Columns with high identical counts indicate redundancy; columns with variation highlight inconsistencies.
#
#
# Step 4: Visualizing the Distribution of Duplicates
#
# Duplicates were visualized using bar charts and pie charts, showing how duplicates are distributed by Country and Employment.
# This step helped confirm whether duplicates were concentrated in certain categories.
# By Country
# Bar chart
# duplicates_subset = df[df.duplicated(subset=subset_cols, keep=False)]
# country_counts = duplicates_subset['Country'].value_counts().head(15)
#
# plt.figure(figsize=(12,6))
# sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")
# plt.xticks(rotation=45, ha='right')
# plt.title("Top 15 Countries with Duplicates")
# plt.ylabel("Number of Duplicates")
# plt.xlabel("Country")
# plt.tight_layout()
# plt.show()
#
# Pie Chart
# plt.figure(figsize=(8,8))
# plt.pie(country_counts.values, labels=country_counts.index, autopct='%1.1f%%')
# plt.title("Duplicate Distribution by Country")
# plt.show()
#
# By Employment
# Bar chart
# employment_counts = duplicates_subset['Employment'].value_counts().head(10)
#
# plt.figure(figsize=(12,6))
# sns.barplot(x=employment_counts.index, y=employment_counts.values, palette="viridis")
# plt.xticks(rotation=45, ha='right')
# plt.title("Distribution of Duplicates by Employment")
# plt.ylabel("Number of Duplicates")
# plt.xlabel("Employment Type")
# plt.tight_layout()
# plt.show()
#
# Pie Chart
# plt.figure(figsize=(8,8))
# plt.pie(employment_counts.values, labels=employment_counts.index, autopct='%1.1f%%')
# plt.title("Duplicate Distribution by Employment")
# plt.show()
#
# Bar charts and pie charts provide both absolute and proportional views of duplicate distribution.
# This helps identify categories most affected by redundancy
#
#
# Step 5: Removing Duplicates Strategically
#
# After evaluating the structure of duplicates, the final dataset was cleaned by removing duplicates based on ResponseId:
#
# df_cleaned = df.drop_duplicates(subset=['ResponseId'], keep='first')
#
# This ensures one record per respondent.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
#
# 2. Explain the Reasoning Behind Selecting Specific Columns for Identifying and Removing Duplicates
#
# The selection of the columns
# ['ResponseId', 'MainBranch', 'Age', 'Country', 'Employment', 'RemoteWork']
# was based on the following considerations:
#
# a. ResponseId
#
# This is the strongest unique identifier in the dataset.
#
# Repeated ResponseId values strongly indicate multiple submissions by the same person.
#
# Therefore, it was used for the final duplicate removal.
#
# b. MainBranch
#
# Indicates the respondent’s primary role or affiliation with programming.
#
# Duplicates with identical MainBranch typically reflect the same user profile.
#
# c. Age
#
# Age tends to remain consistent for an individual, making it reliable for grouping potential duplicate entries.
#
# d. Country
#
# Respondents rarely change countries between survey submissions.
#
# Useful for identifying likely identity-based duplicates.
#
# e. Employment
#
# Employment status reflects personal circumstances that typically remain stable.
#
# When repeated across rows, it strengthens the duplicate match.
#
# f. RemoteWork
#
# Similar to Employment, this variable represents a stable characteristic.
#
# High match likelihood across duplicate entries.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
