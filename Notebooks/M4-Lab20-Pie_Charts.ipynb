# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns   

# Load the data
df = pd.read_csv("survey_data.csv")

pd.get_option("display.max_columns", None)

# Display the first few rows to understand the structure of the data
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
df['DatabaseWantToWorkWith'].unique()
# Out:
# array([nan, 'PostgreSQL', 'Firebase Realtime Database', ...,
#        'Cassandra;Firebase Realtime Database;MariaDB;Microsoft Access;MongoDB;MySQL;PostgreSQL;Redis',
#        'MySQL;Presto;TiDB',
#        'BigQuery;Cassandra;Databricks SQL;DuckDB;Elasticsearch;Firebase Realtime Database;Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;Redis;Snowflake;SQLite;Supabase'],
#       shape=(8479,), dtype=object)

# %%
##Write your code here
db_tw = df['DatabaseWantToWorkWith'].dropna()

db_tw = db_tw.str.split(';').explode()

# %%
top5_dbtw = db_tw.value_counts().head(5)

# %%
plt.pie(
    top5_dbtw,
    labels=top5_dbtw.index,
    autopct='%1.1f%%',
    colors=plt.cm.tab20.colors
)
plt.title('Top 5 Databases Respondents Want to Work With')
# Out:
# Text(0.5, 1.0, 'Top 5 Databases Respondents Want to Work With')

# %% [markdown]
# PostgreSQL is the most popular database among the respondents in the top 5 list with a percentage of 33.5.

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
df['DevType'].unique()
# Out:
# array([nan, 'Developer, full-stack', 'Developer Experience', 'Student',
#        'Academic researcher', 'Project manager', 'Developer Advocate',
#        'Developer, back-end', 'Other (please specify):',
#        'Developer, front-end', 'Database administrator',
#        'Developer, desktop or enterprise applications',
#        'Cloud infrastructure engineer',
#        'Data scientist or machine learning specialist',
#        'Research & Development role',
#        'Developer, embedded applications or devices',
#        'System administrator', 'DevOps specialist', 'Engineering manager',
#        'Designer', 'Security professional',
#        'Senior Executive (C-Suite, VP, etc.)', 'Developer, mobile',
#        'Developer, game or graphics', 'Data or business analyst',
#        'Educator', 'Developer, QA or test', 'Product manager',
#        'Developer, AI', 'Scientist', 'Engineer, site reliability',
#        'Blockchain', 'Marketing or sales professional',
# ...

# %%
df_dev_type = df['DevType'].dropna()
top5_dev_types = df_dev_type.value_counts().head(5)

# %%
plt.pie(
    top5_dev_types,
    labels=top5_dev_types.index,
    autopct='%1.1f%%',
    colors=plt.cm.tab20.colors
)
plt.title('Top 5 Developer Types Among Respondents')
# Out:
# Text(0.5, 1.0, 'Top 5 Developer Types Among Respondents')

# %% [markdown]
# Fullstack developer has the highest percentage among the respondents in the top 5 developer roles.

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
##Write your code here
df['OpSysProfessional use'].unique()
# Out:
# array([nan, 'MacOS', 'Windows', ..., 'ChromeOS;iOS;MacOS;Red Hat;Windows',
#        'Android;MacOS;Windows Subsystem for Linux (WSL)',
#        'BSD;Cygwin;Debian;Fedora;iOS;MacOS;Other Linux-based;Red Hat;Windows;Windows Subsystem for Linux (WSL)'],
#       shape=(2033,), dtype=object)

# %%
df_os = df['OpSysProfessional use'].dropna()
top5_os = df_os.value_counts().head(5)

# %%
plt.pie(
    top5_os,
    labels=top5_os.index,
    autopct='%1.1f%%',
    colors=plt.cm.tab20.colors)
plt.title('Top 5 Operating Systems Used by Developers')
# Out:
# Text(0.5, 1.0, 'Top 5 Operating Systems Used by Developers')

# %% [markdown]
# Windows and MacOS is the most used operating system by the developers as indicated by the chart

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
df['LanguageHaveWorkedWith'].unique()
# Out:
# array([nan,
#        'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript',
#        'C#', ...,
#        'Bash/Shell (all shells);C;C#;C++;Delphi;Groovy;HTML/CSS;Java;JavaScript;Objective-C;PowerShell;Python;SQL;Swift;TypeScript',
#        'C;C++;Go;Lua;Objective-C;Python;Rust;SQL',
#        'C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript'],
#       shape=(23865,), dtype=object)

# %%
df_lang = df['LanguageHaveWorkedWith'].dropna()
df_lang = df_lang.str.split(';').explode()
df_lang
# Out:
# 1        Bash/Shell (all shells)
# 1                             Go
# 1                       HTML/CSS
# 1                           Java
# 1                     JavaScript
#                   ...
# 65436                       Java
# 65436                 JavaScript
# 65436                        PHP
# 65436                     Python
# 65436                 TypeScript
# Name: LanguageHaveWorkedWith, Length: 322233, dtype: object

# %%
top5_lang = df_lang.value_counts().head(5)

# %%
plt.pie(
    top5_lang.values,
    labels=top5_lang.index,
    autopct='%1.1f%%',
    startangle=140
)

plt.title('Top 5 Programming Languages Worked With')
# Out:
# Text(0.5, 1.0, 'Top 5 Programming Languages Worked With')

# %% [markdown]
# The pie chart inicates that JavaScript is the language that most respondents have worked with at 24.4% in the top 5

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
df['NEWCollabToolsHaveWorkedWith'].unique()
# Out:
# array([nan, 'PyCharm;Visual Studio Code;WebStorm', 'Visual Studio', ...,
#        'Android Studio;IntelliJ IDEA;Jupyter Notebook/JupyterLab;Neovim;PyCharm;Visual Studio Code',
#        'PhpStorm;RubyMine;Vim;Visual Studio Code;WebStorm',
#        'DataGrip;IntelliJ IDEA;PyCharm;Rider;Sublime Text;Vim;Visual Studio;Visual Studio Code;WebStorm;Xcode'],
#       shape=(14169,), dtype=object)

# %%
df_tools = df['NEWCollabToolsHaveWorkedWith'].dropna()
df_tools = df_tools.str.split(';').explode()
# Out:
# np.int64(0)

# %%
top5_tools = df_tools.value_counts().head(10)

# %%
plt.pie(
    top5_tools,
    labels=top5_tools.index,
    autopct='%1.1f%%',
    colors=plt.cm.tab20.colors
)
plt.title('Top 10 Collaboration Tools Used by Developers')
# Out:
# Text(0.5, 1.0, 'Top 10 Collaboration Tools Used by Developers')

# %% [markdown]
# Visual studio code is the top collaboration tool used by developers.

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
df['LanguageAdmired'].unique()
# Out:
# array([nan,
#        'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript',
#        'C#', ..., 'Elixir;Lua;Python;Ruby;SQL',
#        'Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;PowerShell;Rust;Solidity;SQL;TypeScript;VBA;Visual Basic (.Net)',
#        'Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;Objective-C;Python;SQL;Swift;TypeScript'],
#       shape=(12336,), dtype=object)

# %%
df_lang_admired = df['LanguageAdmired'].dropna()
df_lang_admired = df_lang_admired.str.split(';').explode()

# %%
top5_lang_admired = df_lang_admired.value_counts().head(5)

# %%
plt.pie(
    top5_lang_admired,
    labels=top5_lang_admired.index,
    autopct='%1.1f%%',
    colors=plt.cm.tab20.colors
)
plt.title('Top 5 Most Admired Programming Languages')
# Out:
# Text(0.5, 1.0, 'Top 5 Most Admired Programming Languages')

# %% [markdown]
# Javascript is the top most admired programming languages among the top 5

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
df['AIToolCurrently Using'].unique()
# Out:
# array([nan,
#        'Learning about a codebase;Project planning;Writing code;Documenting code;Debugging and getting help;Deployment and monitoring;Search for answers;Generating content or synthetic data',
#        'Writing code;Debugging and getting help', ...,
#        'Learning about a codebase;Project planning;Writing code;Debugging and getting help;Testing code;Committing and reviewing code;Deployment and monitoring;Predictive analytics;Search for answers;Generating content or synthetic data;Other (please specify):',
#        'Learning about a codebase;Project planning;Writing code;Testing code;Committing and reviewing code;Search for answers;Generating content or synthetic data;Other (please specify):',
#        'Learning about a codebase;Writing code;Committing and reviewing code;Deployment and monitoring;Predictive analytics;Search for answers'],
#       shape=(1311,), dtype=object)

# %%
df_tools_current = df['AIToolCurrently Using'].dropna()
df_tools_current = df_tools_current.str.split(';').explode()
df_tools_current
# Out:
# 3                   Learning about a codebase
# 3                            Project planning
# 3                                Writing code
# 3                            Documenting code
# 3                  Debugging and getting help
#                          ...
# 65432                        Project planning
# 65432                            Writing code
# 65432                        Documenting code
# 65432                      Search for answers
# 65432    Generating content or synthetic data
# Name: AIToolCurrently Using, Length: 135131, dtype: object

# %%
top5_tools_current = df_tools_current.value_counts().head(5)

# %%
plt.pie(
    top5_tools_current,
    labels=top5_tools_current.index,
    autopct='%1.1f%%',
    colors=plt.cm.tab20.colors,
)
plt.title('Top 5 AI Tools Currently Used by Developers')
# Out:
# Text(0.5, 1.0, 'Top 5 AI Tools Currently Used by Developers')

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
df['WebframeWantToWorkWith'].unique()
# Out:
# array([nan, 'Express;Htmx;Node.js;React;Remix', 'ASP.NET CORE', ...,
#        'Deno;Express;Fastify;Flask;NestJS;Node.js',
#        'ASP.NET;Laravel;React;Spring Boot',
#        'Django;Express;Laravel;NestJS;Next.js;Node.js;Nuxt.js;React;Spring Boot;Symfony;Vue.js;WordPress'],
#       shape=(11655,), dtype=object)

# %%
df_framework = df['WebframeWantToWorkWith'].dropna()
df_framework = df_framework.str.split(';').explode()
df_framework
# Out:
# 1        Express
# 1           Htmx
# 1        Node.js
# 1          React
# 1          Remix
#           ...
# 65436     Django
# 65436    Express
# 65436    Next.js
# 65436    Node.js
# 65436      React
# Name: WebframeWantToWorkWith, Length: 133257, dtype: object

# %%
top5_framework = df_framework.value_counts().head(5)

# %%
plt.pie(
    top5_framework,
    labels=top5_framework.index,
    autopct='%1.1f%%',
    colors=plt.cm.tab20.colors
)
plt.title('Top 5 Web Frameworks Developers Want to Work With')
# Out:
# Text(0.5, 1.0, 'Top 5 Web Frameworks Developers Want to Work With')

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
df['EmbeddedWantToWorkWith'].unique()
# Out:
# array([nan, 'Rasberry Pi', 'CMake;Rasberry Pi', ...,
#        "Boost.Test;build2;cppunit;GNU GCC;LLVM's Clang;MSVC;PlatformIO",
#        'Boost.Test;cppunit;CUTE;MSVC;Ninja;PlatformIO;ZMK',
#        'Catch2;CMake;GNU GCC;PlatformIO'], shape=(1472,), dtype=object)

# %%
df_embedded = df['EmbeddedWantToWorkWith'].dropna()
df_embedded = df_embedded.str.split(';').explode()
df_embedded
# Out:
# 2        Rasberry Pi
# 4              CMake
# 4        Rasberry Pi
# 5        Rasberry Pi
# 15       Rasberry Pi
#             ...
# 65333    Rasberry Pi
# 65371    Rasberry Pi
# 65435          Cargo
# 65435        GNU GCC
# 65435    Rasberry Pi
# Name: EmbeddedWantToWorkWith, Length: 42956, dtype: object

# %%
top5_embedded = df_embedded.value_counts().head(5)

# %%
plt.pie(
    top5_embedded,
    labels=top5_embedded.index,
    autopct='%1.1f%%',
    colors=plt.cm.tab20.colors,
)
plt.title('Top 5 Embedded Systems Developers Want to Work With')
# Out:
# Text(0.5, 1.0, 'Top 5 Embedded Systems Developers Want to Work With')

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
